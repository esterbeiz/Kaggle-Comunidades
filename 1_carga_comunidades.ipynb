# %%
"""
Uses the historical list of Kaggle competitions from here:
https://github.com/EliotAndres/kaggle-past-solutions/blob/master/competitions.yaml 

And outputs a CSV file with same information.
"""
import yaml
import pandas as pd
import json


stream = open('competitions.yaml', 'r')
cs = json.dumps(yaml.load(stream))
competitions = pd.read_json(cs, orient='records')
del competitions['userHasEntered'] # Relative to the user getting the data, irrelevant.
competitions.to_csv('competitions.csv', index=False)

# %%
"""
Takes a file with Kaggle competition data and outputs a file with the private leaderboards.
It uses competitionId and the internal API used in Kaggle web site (not scraping or the official API).
"""

import pandas as pd
import requests as rq
import time
import json

url = 'https://kaggle.com/c/{}/leaderboard.json?includeBeforeUser=true&includeAfterUser=false&type=private'
competitions = pd.read_csv('competitions.csv')

t = []
for _, row in competitions.iterrows():
    print("Getting data for competition:" + str(row['competitionId']))
    r = rq.get(url.format(row['competitionId']))
    res = r.json()
    if isinstance(res, dict) and res.get("beforeUser", False):
        t.extend(map(lambda x: x.update({'competitionId':row['competitionId']}) or x, res["beforeUser"]))
    if isinstance(res, dict) and res.get("afterUser", False):
        t.extend(map(lambda x: x.update({'competitionId':row['competitionId']}) or x, res["afterUser"]))
    time.sleep(1) # just to be polite to Kaggle.

teams = pd.read_json(json.dumps(t), orient='records')

#----
# Getting a new column to identify teams as (teamName attribute is not unique for members)
# the set of users.
#-----
def getUniqueTeamMembers(teamMembers):
    return sorted(set([t['profileUrl'] for t in teamMembers]))

teams["realTeam"] = teams['teamMembers'].map(getUniqueTeamMembers)


teams.to_csv('teams.csv', index=False)


# ---- Alternative scraping code (finally it was not necessary).
# from requests_html import HTMLSession
#session = HTMLSession()
#r = session.get(url + row['competitionUrl']+ '/leaderboard') 
#r.html.render(sleep=3) # Load as a Web browser will do
#teams = r.html.xpath("//tr[contains(@class, 'competition-leaderboard__row')]")
#for t in teams:
#    print(t.xpath("//td[contains(@class, 'competition-leaderboard__td-team')]/text()"))
#session.close()
#time.sleep(5)
# Out:
# Getting data for competition:6004
# Getting data for competition:4699
# Getting data for competition:4571
# Getting data for competition:4657
# Getting data for competition:4494
# Getting data for competition:4504
# Getting data for competition:4704
# Getting data for competition:4521
# Getting data for competition:4594
# Getting data for competition:4523
# Getting data for competition:4487
# Getting data for competition:4493
# Getting data for competition:4488
# Getting data for competition:4481
# Getting data for competition:4467
# Getting data for competition:4471
# Getting data for competition:4453
# Getting data for competition:4438
# Getting data for competition:4104
# Getting data for competition:4407
# Getting data for competition:4366
# Getting data for competition:4280
# Getting data for competition:4272
# Getting data for competition:4066
# Getting data for competition:3978
# Getting data for competition:4031
# Getting data for competition:4120
# Getting data for competition:3973
# Getting data for competition:3984
# Getting data for competition:3887
# Getting data for competition:3951
# Getting data for competition:3929
# Getting data for competition:3897
# Getting data for competition:3778
# Getting data for competition:3788
# Getting data for competition:3706
# Getting data for competition:3867
# Getting data for competition:3757
# Getting data for competition:3670
# Getting data for competition:3532
# Getting data for competition:3618
# Getting data for competition:3599
# Getting data for competition:3504
# Getting data for competition:3526
# Getting data for competition:2969
# Getting data for competition:3403
# Getting data for competition:3525
# Getting data for competition:3338
# Getting data for competition:3445
# Getting data for competition:3446
# Getting data for competition:3493
# Getting data for competition:3316
# Getting data for competition:3469
# Getting data for competition:3353
# Getting data for competition:2496
# Getting data for competition:3342
# Getting data for competition:3288
# Getting data for competition:3294
# Getting data for competition:3108
# Getting data for competition:3043
# Getting data for competition:2975
# Getting data for competition:2863
# Getting data for competition:2963
# Getting data for competition:2840
# Getting data for competition:2780
# Getting data for competition:2748
# Getting data for competition:2749
# Getting data for competition:2667
# Getting data for competition:2732
# Getting data for competition:2889
# Getting data for competition:2602
# Getting data for competition:2606
# Getting data for competition:3321
# Getting data for competition:2589
# Getting data for competition:2564
# Getting data for competition:2551
# Getting data for competition:2609
# Getting data for competition:2549
# Getting data for competition:2509
# Getting data for competition:2518
# Getting data for competition:2499
# Getting data for competition:2487
# Getting data for competition:2489
# Getting data for competition:2479
# Getting data for competition:2488
# Getting data for competition:2478
# Getting data for competition:2445
# Getting data for competition:2467
# Getting data for competition:2454
# Getting data for competition:2464
# Getting data for competition:2452
# Getting data for competition:2447
# Getting data for competition:2439
# Getting data for competition:2448
# Getting data for competition:2435
# Getting data for competition:2438
# Getting data for competition:2442
# Getting data for competition:2408
# Getting data for competition:5558
# Getting data for competition:5357
# Getting data for competition:5261
# Getting data for competition:5340
# Getting data for competition:5260
# Getting data for competition:5144
# Getting data for competition:5048
# Getting data for competition:5174
# Getting data for competition:5229
# Getting data for competition:5056
# Getting data for competition:4986
# Getting data for competition:4853
# Getting data for competition:4852
# Getting data for competition:4862
# Getting data for competition:4729
# Getting data for competition:5497
# Getting data for competition:5916
# Getting data for competition:5874
# Getting data for competition:5390
# Getting data for competition:6116
# Getting data for competition:6243
# Getting data for competition:6277
# Getting data for competition:6049
# Getting data for competition:5568
# Getting data for competition:6644
# Getting data for competition:6322
# Getting data for competition:6565
# Getting data for competition:6392
# Getting data for competition:6649
# Getting data for competition:6775
# Getting data for competition:7115
# Getting data for competition:7082
# Getting data for competition:6927
# Getting data for competition:7391
# Getting data for competition:7634
# Getting data for competition:7559
# Getting data for competition:8078
# Getting data for competition:7277
# Getting data for competition:7380
# Getting data for competition:9949
# Getting data for competition:9951
# Getting data for competition:9120
# Getting data for competition:9717
# Getting data for competition:7878
# Getting data for competition:9301
# Getting data for competition:8586
# Getting data for competition:8540
# Getting data for competition:8089
# Getting data for competition:8310
# Getting data for competition:8311
# Getting data for competition:8076

# %%
"""
"""
import pandas as pd
import numpy as np
import networkx as nx
import ast


competitions = pd.read_csv('competitions.csv', parse_dates=['deadline'])
teams = pd.read_csv('teams.csv')

G = nx.Graph()
G.add_nodes_from(competitions['competitionId'])
for key, n in G.nodes.items():
   n["type"] = "competition"
   n["name"] = competitions[competitions.competitionId == key]["competitionTitle"].values[0]
   n["url"] = competitions[competitions.competitionId == key]["competitionUrl"].values[0]


#----
# Getting a new column to identify teams as (teamName attribute is not unique for members)
# the set of users.
#-----
def getUniqueTeamMembers(teamMembers):
    """Gets a Series of strings, evaluates them as Python objects,
    gets the profile URL and then return the sorted sequence.
    """
    return sorted([t["profileUrl"] for t in ast.literal_eval(teamMembers)])

teams["realTeam"] = teams['teamMembers'].map(getUniqueTeamMembers)
print("Number of different teams:"+ str(len(teams.realTeam.transform(tuple).unique())))


G.add_nodes_from(teams.realTeam.transform(tuple).unique(), type="team")


comp_teams = np.column_stack((teams['competitionId'].values, teams['realTeam'].transform(tuple).values))
print(comp_teams)
G.add_edges_from(comp_teams)
nx.write_graphml(G, 'kaggle.xml')
# Out:
# Number of different teams:77566
# [[6004 ('/badrobot', '/grt123', '/liaofz')]
#  [6004 ('/dhammack', '/juliandewit')]
#  [6004 ('/gerbenvv', '/markjan', '/timsalimans')]
#  ...
#  [8076 ('/ayanmaity',)]
#  [8076 ('/msafi04',)]
#  [8076 ('/george96uoi',)]]

# %%
import matplotlib.pyplot as plt
nx.draw_networkx(G, with_labels=True)
plt.show()
# Out:
# C:\Users\Usuario\Anaconda3\lib\site-packages\networkx\drawing\layout.py:499: RuntimeWarning: invalid value encountered in sqrt
#   distance = np.sqrt((delta**2).sum(axis=0))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\networkx\drawing\layout.py in fruchterman_reingold_layout(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, random_state)
#     352                                            iterations, threshold,
# --> 353                                            dim, random_state)
#     354     except:
#
# <decorator-gen-601> in _sparse_fruchterman_reingold(A, k, pos, fixed, iterations, threshold, dim, random_state)
#
# ~\Anaconda3\lib\site-packages\networkx\utils\decorators.py in _random_state(func, *args, **kwargs)
#     386         new_args[random_state_index] = random_state_instance
# --> 387         return func(*new_args, **kwargs)
#     388     return _random_state
#
# ~\Anaconda3\lib\site-packages\networkx\drawing\layout.py in _sparse_fruchterman_reingold(A, k, pos, fixed, iterations, threshold, dim, random_state)
#     505             displacement[:, i] +=\
# --> 506                 (delta * (k * k / distance**2 - Ai * distance / k)).sum(axis=1)
#     507         # update positions
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims)
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# MemoryError                               Traceback (most recent call last)
# <ipython-input-4-cc2b7c1f8835> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 nx.draw_networkx(G, with_labels=True)
#       3 plt.show()
#
# ~\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     273
#     274     if pos is None:
# --> 275         pos = nx.drawing.spring_layout(G)  # default to spring layout
#     276
#     277     node_collection = draw_networkx_nodes(G, pos, **kwds)
#
# <decorator-gen-597> in fruchterman_reingold_layout(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, random_state)
#
# ~\Anaconda3\lib\site-packages\networkx\utils\decorators.py in _random_state(func, *args, **kwargs)
#     385         new_args = list(args)
#     386         new_args[random_state_index] = random_state_instance
# --> 387         return func(*new_args, **kwargs)
#     388     return _random_state
#
# ~\Anaconda3\lib\site-packages\networkx\drawing\layout.py in fruchterman_reingold_layout(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, random_state)
#     353                                            dim, random_state)
#     354     except:
# --> 355         A = nx.to_numpy_matrix(G, weight=weight)
#     356         if k is None and fixed is not None:
#     357             # We must adjust k by domain size for layouts not near 1x1
#
# ~\Anaconda3\lib\site-packages\networkx\convert_matrix.py in to_numpy_matrix(G, nodelist, dtype, order, multigraph_weight, weight, nonedge)
#     446     A = to_numpy_array(G, nodelist=nodelist, dtype=dtype, order=order,
#     447                        multigraph_weight=multigraph_weight, weight=weight,
# --> 448                        nonedge=nonedge)
#     449     M = np.asmatrix(A, dtype=dtype)
#     450     return M
#
# ~\Anaconda3\lib\site-packages\networkx\convert_matrix.py in to_numpy_array(G, nodelist, dtype, order, multigraph_weight, weight, nonedge)
#    1122     else:
#    1123         # Graph or DiGraph, this is much faster than above
# -> 1124         A = np.full((nlen, nlen), np.nan, order=order)
#    1125         for u, nbrdict in G.adjacency():
#    1126             for v, d in nbrdict.items():
#
# ~\Anaconda3\lib\site-packages\numpy\core\numeric.py in full(shape, fill_value, dtype, order)
#     296     if dtype is None:
#     297         dtype = array(fill_value).dtype
# --> 298     a = empty(shape, dtype, order)
#     299     multiarray.copyto(a, fill_value, casting='unsafe')
#     300     return a
#
# MemoryError:

# %%
print('Número de nodos:')
print(len(list(G.nodes())))
print('Número de aristas:')
print(len(list(G.edges())))
print('Densidad:')
print(nx.density(G))
# Out:
# Número de nodos:
# 77715
# Número de aristas:
# 148039
# Densidad:
# 4.9023241493296234e-05

# %%
degree_list = []
for v in G:
    degree_list.append(G.degree(v))

print('Max degree:')
print(max(degree_list))
print('Min degree:')
print(min(degree_list))
print('Average degree:')
print(sum(degree_list)/len(degree_list))
# Out:
# Max degree:
# 7188
# Min degree:
# 0
# Average degree:
# 3.809792189410024

# %%
import networkx as nx

# %%
print(nx.is_connected(G))
# Out:
# False

# %%
print(nx.number_connected_components(G))
# Out:
# 3

# %%
print(nx.is_directed(G))
# Out:
# False

# %%
sorted(G.degree, key=lambda x: x[1], reverse=True)
# Out:
# [(9120, 7188),
#  (7082, 5162),
#  (4986, 5119),
#  (8076, 4547),
#  (9717, 4469),
#  (8540, 3951),
#  (6565, 3829),
#  (6649, 3777),
#  (4280, 3511),
#  (7380, 3339),
#  (4594, 3303),
#  (6277, 3300),
#  (6392, 3269),
#  (4852, 2922),
#  (6644, 2623),
#  (4699, 2616),
#  (7559, 2382),
#  (5261, 2266),
#  (4272, 2258),
#  (4471, 2234),
#  (4487, 2225),
#  (7277, 2153),
#  (4853, 2126),
#  (5874, 2071),
#  (5056, 1973),
#  (5260, 1966),
#  (8586, 1871),
#  (3887, 1788),
#  (5558, 1784),
#  (4657, 1759),
#  (3338, 1688),
#  (5340, 1684),
#  (7391, 1673),
#  (4120, 1604),
#  (3788, 1568),
#  (4031, 1528),
#  (5048, 1440),
#  (5357, 1372),
#  (2496, 1353),
#  (4407, 1327),
#  (4467, 1323),
#  (7634, 1315),
#  (4366, 1307),
#  (4704, 1127),
#  (4481, 1076),
#  (3978, 1050),
#  (5497, 979),
#  (3897, 951),
#  (6322, 937),
#  (8310, 935),
#  (2551, 925),
#  (5144, 924),
#  (4504, 833),
#  (8089, 743),
#  (6927, 735),
#  (2780, 699),
#  (4488, 674),
#  (4104, 662),
#  (2748, 658),
#  (6049, 655),
#  (7878, 652),
#  (3951, 634),
#  (7115, 627),
#  (3526, 626),
#  (4862, 598),
#  (8078, 580),
#  (2564, 571),
#  (3445, 554),
#  (5174, 548),
#  (3599, 532),
#  (8311, 505),
#  (5390, 479),
#  (3316, 476),
#  (9949, 454),
#  (3973, 439),
#  (5916, 420),
#  (4438, 414),
#  (5229, 400),
#  (6004, 395),
#  (5568, 389),
#  (6116, 386),
#  (3984, 377),
#  (4521, 365),
#  (2840, 364),
#  (3670, 363),
#  (3294, 355),
#  (2467, 355),
#  (4066, 342),
#  (4453, 339),
#  (3504, 337),
#  (9301, 313),
#  (3342, 290),
#  (3929, 286),
#  (2518, 277),
#  (4493, 274),
#  (2732, 264),
#  (6243, 261),
#  (2489, 259),
#  (2447, 252),
#  (3706, 249),
#  (3353, 246),
#  (3108, 244),
#  (3446, 239),
#  (2606, 239),
#  (2975, 237),
#  (9951, 232),
#  (3288, 223),
#  (3867, 206),
#  (2445, 204),
#  (2609, 202),
#  (3532, 195),
#  (4729, 192),
#  (2479, 181),
#  (2478, 176),
#  (4571, 171),
#  (2969, 166),
#  (2749, 164),
#  (3043, 162),
#  (2667, 155),
#  (6775, 149),
#  (2439, 145),
#  (2963, 134),
#  (3469, 133),
#  (2464, 117),
#  (2589, 112),
#  (2889, 110),
#  (3493, 109),
#  (2435, 107),
#  (2509, 104),
#  (2499, 91),
#  (3403, 81),
#  (('/invinciblejha',), 81),
#  (('/lawrencechernin',), 77),
#  (2487, 72),
#  (('/alexxanderlarko',), 69),
#  (('/mikeskim',), 66),
#  (('/datenkieker',), 66),
#  (('/vadims',), 65),
#  (('/carloshuertas',), 64),
#  (2442, 63),
#  (('/lucamassaron',), 63),
#  (('/dominique',), 63),
#  (('/jeffhebert',), 61),
#  (('/ivanhoe',), 61),
#  (4523, 60),
#  (('/jpmiller',), 60),
#  (('/aymankh',), 60),
#  (('/mathurinache',), 59),
#  (('/ceshine',), 59),
#  (('/clustifier',), 59),
#  (('/chipmonkey',), 59),
#  (('/liderchang',), 59),
#  (('/confirm',), 59),
#  (2454, 57),
#  (('/ryutek',), 57),
#  (2448, 55),
#  (('/willieliao',), 55),
#  (('/thakurrajanand',), 55),
#  (('/nileshkadam',), 55),
#  (('/vlarine',), 54),
#  (('/domcastro',), 54),
#  (('/telcontar120',), 54),
#  (('/engenious',), 53),
#  (('/hamelg',), 53),
#  (('/nedelko',), 52),
#  (('/niranjanmudhiraj',), 52),
#  (3757, 51),
#  (('/tunguz',), 51),
#  (('/milivojevic',), 50),
#  (('/damianmingle',), 50),
#  (('/wcukierski',), 49),
#  (('/scirpus',), 49),
#  (2602, 48),
#  (('/agavranis',), 48),
#  (('/akilaw',), 48),
#  (('/weizhezhang',), 48),
#  (('/janosk21',), 47),
#  (('/andrekos',), 47),
#  (('/zhugds',), 47),
#  (('/huibers',), 47),
#  (('/mathusuthan',), 46),
#  (('/comanda',), 46),
#  (('/nilotpal',), 45),
#  (('/mingjerli',), 45),
#  (('/benhamner',), 45),
#  (3778, 44),
#  (('/mzacks',), 44),
#  (('/gmobaz',), 44),
#  (('/abhishek',), 43),
#  (2452, 42),
#  (('/spimenov',), 42),
#  (('/theanalyticprophet',), 42),
#  (('/voltaire',), 42),
#  (('/tshlckk',), 42),
#  (4494, 41),
#  (('/zfturbo',), 41),
#  (('/del=121b7398bccb8e5a',), 41),
#  (('/niranjanmaisnam',), 41),
#  (('/julesvanligtenberg',), 40),
#  (('/androidhk',), 40),
#  (('/sionek',), 40),
#  (('/karma86',), 40),
#  (('/soumojit86',), 40),
#  (('/robwishart',), 40),
#  (('/symyksr',), 39),
#  (('/paulorzp',), 39),
#  (('/barisumog',), 39),
#  (('/jtrotman',), 39),
#  (('/michaelpawlus',), 39),
#  (3618, 38),
#  (('/nigelcarpenter',), 38),
#  (('/krishnakesavan',), 38),
#  (('/jeongyoonlee',), 38),
#  (('/cubbus',), 38),
#  (('/seabreeze',), 38),
#  (('/manueldiaz',), 38),
#  (('/mindcool',), 37),
#  (('/alijs1',), 37),
#  (('/girmak',), 37),
#  (('/tyi2000',), 37),
#  (('/interesting',), 37),
#  (('/georgem',), 37),
#  (('/yangyanzhan',), 37),
#  (('/yashwanthreddy',), 37),
#  (('/amunategui',), 37),
#  (('/michelblaauw',), 37),
#  (('/kazanova',), 36),
#  (('/psilogram',), 36),
#  (('/dimitrislev',), 36),
#  (('/sujeeth',), 36),
#  (('/chandrad',), 36),
#  (('/datafad',), 36),
#  (('/sekrier',), 35),
#  (('/dhegde',), 35),
#  (('/inversion',), 35),
#  (('/soumendra',), 35),
#  (('/jianminsun',), 35),
#  (('/naokazumizuta',), 35),
#  (('/blindape',), 35),
#  (('/mandelbrot',), 34),
#  (('/santiagomota',), 34),
#  (('/panosc',), 34),
#  (('/tereka',), 34),
#  (('/dremovd',), 34),
#  (('/iglovikov',), 34),
#  (('/tks0123456789',), 34),
#  (('/dynamic24',), 34),
#  (('/sadz2201',), 33),
#  (('/ouranos',), 33),
#  (('/jbm1966',), 33),
#  (('/jamesdlawrence',), 33),
#  (('/paolovigori',), 33),
#  (('/robertmartin71',), 33),
#  (('/anjanaagrawal',), 33),
#  (('/sirguessalot',), 33),
#  (('/razgon',), 32),
#  (('/mlandry',), 32),
#  (('/justfor',), 32),
#  (('/mattvonrohr',), 32),
#  (('/cydonia',), 32),
#  (('/hulkbulk',), 32),
#  (('/tetsurotayama',), 32),
#  (('/glimmung',), 32),
#  (('/cdjbee',), 32),
#  (('/weiwunyc',), 32),
#  (('/iamivo',), 32),
#  (('/reachkishore',), 32),
#  (('/vicensgaitan',), 31),
#  (('/anokas',), 31),
#  (('/titericz',), 31),
#  (('/drpatrickchan',), 31),
#  (('/gshguru',), 31),
#  (('/krashski',), 31),
#  (('/mjahrer',), 31),
#  (('/pmarini',), 31),
#  (('/vladdy',), 31),
#  (2488, 30),
#  (('/marek3000',), 30),
#  (('/dmytrolystopad',), 30),
#  (('/santyago',), 30),
#  (('/pietromarinelli',), 30),
#  (('/marugari',), 30),
#  (('/cttsai',), 30),
#  (('/wendykan',), 30),
#  (('/ginotesei',), 30),
#  (('/vanderakt',), 30),
#  (('/rajapasupuleti',), 30),
#  (2863, 29),
#  (('/woshialex',), 29),
#  (('/jaybob20',), 29),
#  (('/nthanhtam',), 29),
#  (('/vykhand',), 29),
#  (('/lnicalo',), 29),
#  (('/happycube',), 29),
#  (('/openneuron',), 29),
#  (('/del=cca345899d608f0a',), 29),
#  (('/ijaganjac',), 29),
#  (('/rvprasad',), 29),
#  (('/toulouse',), 29),
#  (('/pavitrakumar78',), 29),
#  (('/jasonkarpeles',), 29),
#  (2549, 28),
#  (('/jekyllsmith',), 28),
#  (('/leadbest',), 28),
#  (('/ccccat',), 28),
#  (('/sterby',), 28),
#  (('/lantingguo',), 28),
#  (('/kolachalama',), 28),
#  (('/nemesis2',), 28),
#  (('/liwzhi',), 28),
#  (('/triskelion',), 28),
#  (('/gelanbou',), 28),
#  (('/brendanborin',), 28),
#  (('/gaborfodor',), 28),
#  (('/creafz',), 28),
#  (('/chenglongchen',), 27),
#  (('/nsecord',), 27),
#  (('/linchn',), 27),
#  (('/johnnystrings',), 27),
#  (('/republic966',), 27),
#  (('/jscheibel',), 27),
#  (('/danofer',), 27),
#  (('/sourabhjha',), 27),
#  (('/dowakin',), 27),
#  (('/girishiyer',), 27),
#  (('/dirknbr',), 27),
#  (('/jasonsumpter',), 27),
#  (('/ikretus',), 27),
#  (('/manuelk',), 27),
#  (('/praveenadepu',), 26),
#  (('/ginoainsley',), 26),
#  (('/bernhard1',), 26),
#  (('/roshankr',), 26),
#  (('/jasonnoriega',), 26),
#  (('/lilisun',), 26),
#  (('/mnrlmn',), 26),
#  (('/mikhailz',), 26),
#  (('/yassertabandeh',), 26),
#  (('/davidshinn',), 26),
#  (('/averma',), 26),
#  (('/konradb',), 26),
#  (('/zhukov',), 26),
#  (('/sthompson',), 26),
#  (('/jiweiliu',), 25),
#  (('/parkinsonzabelin',), 25),
#  (('/vetribox',), 25),
#  (('/breakfastpirate',), 25),
#  (('/allmendinger',), 25),
#  (('/luciferase',), 25),
#  (('/bonferroni27',), 25),
#  (('/rrgiles',), 25),
#  (('/anthonyp',), 25),
#  (('/antonov',), 25),
#  (('/manoharswamynathan',), 25),
#  (('/xscripter',), 25),
#  (('/flashnik',), 25),
#  (('/lifepreserver',), 25),
#  (('/jessiecarnegie7777',), 25),
#  (('/gooron',), 25),
#  (('/dyakonov',), 25),
#  (('/skorsun',), 25),
#  (('/tjungblut',), 25),
#  (('/godaibo',), 25),
#  (('/danieleewww',), 24),
#  (('/skylibrary',), 24),
#  (('/ampaho',), 24),
#  (('/kmenou',), 24),
#  (('/manels',), 24),
#  (('/uditsaini',), 24),
#  (('/siddharthbiswal',), 24),
#  (('/greenmtn',), 24),
#  (('/pythonomic',), 24),
#  (('/zachmayer',), 24),
#  (('/phanisrikanth',), 24),
#  (('/sitaram',), 24),
#  (('/cbentes',), 24),
#  (('/anujmehra',), 24),
#  (('/mchahhou',), 24),
#  (('/alexryzhkov',), 24),
#  (('/andreisun',), 24),
#  (('/piotrw',), 24),
#  (('/del=22efbb9d3ecd9fc4',), 24),
#  (('/loweew',), 24),
#  (('/rkirana',), 24),
#  (('/santanuds',), 24),
#  (('/psardin',), 24),
#  (('/nil666',), 24),
#  (('/mineshjethva',), 24),
#  (('/behrang',), 23),
#  (('/welcomeworld',), 23),
#  (('/yilihome',), 23),
#  (('/dakindia',), 23),
#  (('/majhra',), 23),
#  (('/srikiyer',), 23),
#  (('/vishanta',), 23),
#  (('/nirved',), 23),
#  (('/yarmolau',), 23),
#  (('/jofaichow',), 23),
#  (('/abhisheksimhadri',), 23),
#  (('/rudikruger',), 23),
#  (('/morandi',), 23),
#  (('/markpeng',), 23),
#  (('/sharmaharshit',), 23),
#  (('/scharf',), 23),
#  (('/starboard',), 23),
#  (('/yuhaichina',), 23),
#  (('/earino',), 23),
#  (('/ibobriakov',), 23),
#  (('/szhitansky',), 23),
#  (('/thomastilli',), 23),
#  (2408, 22),
#  (('/miguelpm',), 22),
#  (('/raddar',), 22),
#  (('/iris2007',), 22),
#  (('/jayjay75',), 22),
#  (('/gingayoshizawa',), 22),
#  (('/cbourne',), 22),
#  (('/kwartler',), 22),
#  (('/kentsedoro',), 22),
#  (('/sonnylaskar',), 22),
#  (('/achm6174',), 22),
#  (('/tharindudr',), 22),
#  (('/nileshp',), 22),
#  (('/hashkanna',), 22),
#  (('/nkhuyu',), 22),
#  (('/rejulien',), 22),
#  (('/dziduchm',), 22),
#  (('/harshalsoman',), 22),
#  (('/kailex',), 22),
#  (('/gphilippis',), 22),
#  (('/bruno16',), 22),
#  (('/sangsulee',), 22),
#  (('/mennotaanman',), 22),
#  (('/terje62',), 22),
#  (('/devinanzelmo',), 22),
#  (('/frufus123',), 22),
#  (('/ydhiman',), 22),
#  (('/dixitgaurav',), 22),
#  (('/bcragin',), 22),
#  (('/andreybogomolov',), 22),
#  (('/erikerik',), 22),
#  (('/tafkas',), 22),
#  (('/sashikanthdareddy',), 22),
#  (('/sbairishal',), 22),
#  (('/patrickracsa',), 22),
#  (('/bankhv',), 22),
#  (('/eduardoli',), 21),
#  (('/alexeylive',), 21),
#  (('/muhammedazamkhan',), 21),
#  (('/thawatt',), 21),
#  (('/johncandido',), 21),
#  (('/antklen',), 21),
#  (('/vinodmk',), 21),
#  (('/thenx00',), 21),
#  (('/usixuz',), 21),
#  (('/samrotashoka',), 21),
#  (('/alexs00',), 21),
#  (('/tomtillo',), 21),
#  (('/gausschen',), 21),
#  (('/blackcore',), 21),
#  (('/hasanmujtaba',), 21),
#  (('/datastunner',), 21),
#  (('/atulkum',), 21),
#  (('/del=82983f1f36085be7',), 21),
#  (('/hellothere0113',), 21),
#  (('/algonell',), 21),
#  (('/elenacuoco',), 21),
#  (('/rushter',), 21),
#  (('/lclpku',), 21),
#  (('/hustmonk',), 21),
#  (('/phil1985',), 21),
#  (('/bessalov',), 21),
#  (('/andr113',), 21),
#  (('/hurlburt',), 21),
#  (('/brassmonkey381',), 21),
#  (('/juandoso',), 21),
#  (('/adilmouja',), 21),
#  (('/tonyyy',), 21),
#  (('/jialunhe',), 21),
#  (('/aysent',), 21),
#  (('/sigint',), 21),
#  (('/sauravkaushik8',), 21),
#  (('/osamir',), 21),
#  (('/etherqua',), 21),
#  (('/infinitewing',), 21),
#  (('/vanamsen',), 21),
#  (('/speculation',), 20),
#  (('/lishubin',), 20),
#  (('/omoekan09',), 20),
#  (('/innerproduct',), 20),
#  (('/tommontroy',), 20),
#  (('/mconway',), 20),
#  (('/shenwenlong',), 20),
#  (('/grzegorz',), 20),
#  (('/hikomimo',), 20),
#  (('/tolyapro',), 20),
#  (('/andreburk',), 20),
#  (('/jasontam',), 20),
#  (('/d3potf',), 20),
#  (('/samirzach',), 20),
#  (('/millerintllc',), 20),
#  (('/thomasjpfan',), 20),
#  (('/binomka',), 20),
#  (('/toshik',), 20),
#  (('/wacaxx',), 20),
#  (('/amazone',), 20),
#  (('/tobycat',), 20),
#  (('/diogoff',), 20),
#  (('/company',), 20),
#  (('/egyfirst',), 20),
#  (('/x0x0w1',), 20),
#  (('/aamaia',), 20),
#  (('/misfyre',), 20),
#  (('/neongen',), 20),
#  (('/lihaorocky',), 20),
#  (('/panjtan',), 20),
#  (('/fabsod',), 20),
#  (('/arindamgot',), 20),
#  (('/matthiascoste',), 20),
#  (('/kmtbang',), 20),
#  (('/zeemeen',), 20),
#  (('/hitman47',), 20),
#  (('/apoorvc',), 20),
#  (('/gweijie',), 20),
#  (('/junshi',), 19),
#  (('/wakeup06',), 19),
#  (('/chechir',), 19),
#  (('/sudalairajkumar',), 19),
#  (('/tmwright',), 19),
#  (('/mrbeer',), 19),
#  (('/ys19931006',), 19),
#  (('/achursov',), 19),
#  (('/x75a40890',), 19),
#  (('/kapetis',), 19),
#  (('/adornes',), 19),
#  (('/sharkov',), 19),
#  (('/adamwong',), 19),
#  (('/jsh127',), 19),
#  (('/alexeykuklin',), 19),
#  (('/kmalev',), 19),
#  (('/healthactuary',), 19),
#  (('/molozhenko',), 19),
#  (('/lujing',), 19),
#  (('/herrahuu',), 19),
#  (('/magiclogic',), 19),
#  (('/chowdary',), 19),
#  (('/bellar',), 19),
#  (('/anketer',), 19),
#  (('/mpigolkin',), 19),
#  (('/paulmnz',), 19),
#  (('/dslate',), 19),
#  (('/azneye',), 19),
#  (('/inpefess',), 19),
#  (('/borschi',), 19),
#  (('/owenzhang1',), 19),
#  (('/ksjpswaroop',), 19),
#  (('/quansun',), 19),
#  (('/thierrys',), 19),
#  (('/bartekp',), 19),
#  (('/wallinm1',), 19),
#  (('/alxndrkalinin',), 19),
#  (('/viveksha',), 19),
#  (('/edramsden',), 19),
#  (('/joconnor',), 19),
#  (('/kirillal',), 19),
#  (('/rsenthil',), 19),
#  (('/shse77',), 19),
#  (('/gosh76',), 19),
#  (('/savioz',), 19),
#  (('/supreethmanyam',), 19),
#  (('/ymcdull',), 19),
#  (('/pierretisseur',), 19),
#  (('/sheriytm',), 19),
#  (('/dongxu027',), 19),
#  (('/danielfg',), 18),
#  (('/medial',), 18),
#  (('/natbel4ml',), 18),
#  (('/jorgepalma',), 18),
#  (('/jturkewitz',), 18),
#  (('/sushize',), 18),
#  (('/khattab34',), 18),
#  (('/nnsmedia',), 18),
#  (('/lplewa',), 18),
#  (('/rhinodaveb',), 18),
#  (('/thedoctor46',), 18),
#  (('/fernandoprocy',), 18),
#  (('/alexlzzz',), 18),
#  (('/heartyguy',), 18),
#  (('/vettipaiyan',), 18),
#  (('/bikasha',), 18),
#  (('/rajkumarbn',), 18),
#  (('/kgilpas',), 18),
#  (('/gkoundry',), 18),
#  (('/kromil',), 18),
#  (('/khyh00',), 18),
#  (('/girasm',), 18),
#  (('/towelie',), 18),
#  (('/cherishzhang',), 18),
#  (('/jrings',), 18),
#  (('/abhisheknagarjuna',), 18),
#  (('/kirilllisenkov',), 18),
#  (('/madjack',), 18),
#  (('/ramarlina',), 18),
#  (('/namakemono',), 18),
#  (('/rhostam',), 18),
#  (('/del=d155c48030c5d3bf',), 18),
#  (('/lancerts',), 18),
#  (('/ducktile',), 18),
#  (('/jfkingiii',), 18),
#  (('/victorcantor',), 18),
#  (('/tenich',), 18),
#  (('/guidotapia',), 18),
#  (('/makemate',), 18),
#  (('/fabiogabriel',), 18),
#  (('/phillipadkins',), 18),
#  (('/maternaj',), 18),
#  (('/vsu1664',), 18),
#  (('/kubilai',), 18),
#  (('/kylelee',), 18),
#  (('/resolut',), 18),
#  (('/mystery',), 18),
#  (('/voilin',), 18),
#  (('/dysonlin',), 18),
#  (('/nuhsikander',), 18),
#  (('/rluethy',), 17),
#  (('/opanichev',), 17),
#  (('/svesal',), 17),
#  (('/stocks',), 17),
#  (('/dmitrylarko',), 17),
#  (('/matlab',), 17),
#  (('/thodime',), 17),
#  (('/abhilashawasthi',), 17),
#  (('/dougkoch',), 17),
#  (('/cr2015',), 17),
#  (('/tazhoodeen',), 17),
#  (('/emiliocs',), 17),
#  (('/kuo000',), 17),
#  (('/priyansu',), 17),
#  (('/amihalik',), 17),
#  (('/davidsl83',), 17),
#  (('/khaledfayed',), 17),
#  (('/adarshchavakula',), 17),
#  (('/pabloarayamelo',), 17),
#  (('/amitchoudhary',), 17),
#  (('/mal000',), 17),
#  (('/newebug',), 17),
#  (('/onodera',), 17),
#  (('/namlequang',), 17),
#  (('/weilizhang',), 17),
#  (('/data2015',), 17),
#  (('/nishkgp',), 17),
#  (('/charmchi',), 17),
#  (('/dmaust',), 17),
#  (('/chevli',), 17),
#  (('/chok68',), 17),
#  (('/anaconda',), 17),
#  (('/showletter',), 17),
#  (('/zhihui',), 17),
#  (('/parthibangowthaman',), 17),
#  (('/barrenwuffet',), 17),
#  (('/rsakata',), 17),
#  (('/rwieczor',), 17),
#  (('/kymhorsell1',), 17),
#  (('/cjturner',), 17),
#  (('/mpionnier',), 17),
#  (('/shenss',), 17),
#  (('/sjoly123',), 17),
#  (('/tilii7',), 17),
#  (('/krishmahajan',), 17),
#  (('/bcottman',), 17),
#  (('/chandanverma',), 17),
#  (('/johnfarrell',), 17),
#  (('/tetyanayatsenko',), 17),
#  (('/hireme',), 17),
#  (('/victorsd',), 16),
#  (('/bmcinnovo',), 16),
#  (('/eduzznet',), 16),
#  (('/trenqualye',), 16),
#  (('/newtohere',), 16),
#  (('/masandy',), 16),
#  (('/viktxn',), 16),
#  (('/charlesroberson',), 16),
#  (('/codebender',), 16),
#  (('/mandalsubhajit',), 16),
#  (('/hartmut',), 16),
#  (('/nernst',), 16),
#  (('/nishadc',), 16),
#  (('/techface',), 16),
#  (('/manasrkar',), 16),
#  (('/denistsitko',), 16),
#  (('/kotomord',), 16),
#  (('/coolsgd',), 16),
#  (('/adegie',), 16),
#  (('/oneoff',), 16),
#  (('/navdeepgill',), 16),
#  (('/jsrice',), 16),
#  (('/traveller',), 16),
#  (('/uday1889',), 16),
#  (('/jeremypmobley',), 16),
#  (('/khanenko',), 16),
#  (('/u1234x1234',), 16),
#  (('/shrikeler',), 16),
#  (('/sorenravn',), 16),
#  (('/yetiman',), 16),
#  (('/edcrandell',), 16),
#  (('/mattsco',), 16),
#  (('/romanakhunov',), 16),
#  (('/weilinear',), 16),
#  (('/cashfeg',), 16),
#  (('/gertjac',), 16),
#  (('/zygmunt',), 16),
#  (('/abhijitk',), 16),
#  (('/aguerreiro',), 16),
#  (('/melindasmith',), 16),
#  (('/kmsingh',), 16),
#  (('/iosentinel',), 16),
#  (('/keiku322',), 16),
#  (('/alanpo',), 16),
#  (('/ernest',), 16),
#  (('/jeffmoser',), 16),
#  (('/lefant',), 16),
#  (('/ahassaine',), 16),
#  (('/brianelwell',), 16),
#  (('/datascientist1',), 16),
#  (('/ekydna',), 16),
#  (('/kevindiaz',), 16),
#  (('/nitsourish',), 16),
#  (('/ryanzhang',), 16),
#  (('/anilcs',), 16),
#  (('/lalthan',), 16),
#  (('/awangntu',), 16),
#  (('/nifannn',), 16),
#  (('/amitkumarjaiswal',), 16),
#  (('/yyll008',), 16),
#  ((), 16),
#  (('/abdulwahabkabani',), 15),
#  (('/nhargan',), 15),
#  (('/krishnateja614',), 15),
#  (('/chanfuku18',), 15),
#  (('/casalicchio',), 15),
#  (('/fakeplastictrees',), 15),
#  (('/sayantan',), 15),
#  (('/robertkag',), 15),
#  (('/epinephelus',), 15),
#  (('/goalminer',), 15),
#  (('/dlajeunesse',), 15),
#  (('/bgeier',), 15),
#  (('/kishoreb4',), 15),
#  (('/jzaratie',), 15),
#  (('/cjferba',), 15),
#  (('/marcellonegro',), 15),
#  (('/saihttam',), 15),
#  (('/raghparihar',), 15),
#  (('/outliar',), 15),
#  (('/del=da7fe58cd1f23be1',), 15),
#  (('/ciroel',), 15),
#  (('/threeplusme',), 15),
#  (('/hmnshu',), 15),
#  (('/bruttoblotto',), 15),
#  (('/joshstone',), 15),
#  (('/szaroletta',), 15),
#  (('/transplanted',), 15),
#  (('/siddharthshahi',), 15),
#  (('/abednadir',), 15),
#  (('/sunsoutfunsout',), 15),
#  (('/ktts1031',), 15),
#  (('/ggofat',), 15),
#  (('/gbakie',), 15),
#  (('/vkuznet',), 15),
#  (('/maksik',), 15),
#  (('/maggiezhou',), 15),
#  (('/bluearrow',), 15),
#  (('/notsorandomforest',), 15),
#  (('/archieindian',), 15),
#  (('/mdabros',), 15),
#  (('/neuralnetworks',), 15),
#  (('/haimlust',), 15),
#  (('/mostafaelaraby',), 15),
#  (('/vjacomet',), 15),
#  (('/navsun',), 15),
#  (('/luckyguy',), 15),
#  (('/kashnitsky',), 15),
#  (('/vtomecek',), 15),
#  (('/alexeynoskov',), 15),
#  (('/duttaroy',), 15),
#  (('/alielhassouni',), 15),
#  (('/shawn775',), 15),
#  (('/intentia',), 15),
#  (('/alcam1',), 15),
#  (('/davidtran',), 15),
#  (('/jinhui',), 15),
#  (('/amineteffal',), 15),
#  (('/tkm2261',), 15),
#  (('/grizzli3k',), 15),
#  (('/goutam',), 15),
#  (('/srowen',), 15),
#  (('/vikasrtr',), 15),
#  (('/xavierconort',), 15),
#  (('/pbkaran',), 15),
#  (('/pichai',), 15),
#  (('/danielyoo',), 15),
#  (('/jkrijthe',), 15),
#  (('/antgoldbloom',), 15),
#  (('/dieselboy',), 15),
#  (('/piotrkuchta',), 15),
#  (('/donlima',), 15),
#  (('/nmud19',), 15),
#  (('/badoun',), 15),
#  (('/randxie',), 15),
#  (('/chrisw1',), 15),
#  (('/anwarsadique',), 15),
#  (('/sadgnome',), 15),
#  (('/beletecheneke',), 15),
#  (('/shujian',), 15),
#  (('/yekenot',), 15),
#  (('/wanizz',), 15),
#  (('/jessesealand',), 15),
#  (('/akyr88',), 15),
#  (('/bibinpaul',), 15),
#  (('/williamhau',), 14),
#  (('/paragkale',), 14),
#  (('/kelexu',), 14),
#  (('/olegkulikov',), 14),
#  (('/sebda1',), 14),
#  (('/a11rand0m',), 14),
#  (('/vipito',), 14),
#  (('/vladimirmerkulov',), 14),
#  (('/andtem2000',), 14),
#  (('/melvindunn',), 14),
#  (('/suresubs',), 14),
#  (('/howlingguineapig',), 14),
#  (('/reneboy',), 14),
#  (('/rohanrao',), 14),
#  (('/upulbandara',), 14),
#  (('/tkwijaya',), 14),
#  (('/signochastic',), 14),
#  (('/mpearmain',), 14),
#  (('/mrooijer',), 14),
#  (('/cramosu',), 14),
#  (('/malais',), 14),
#  (('/soundwaveli00',), 14),
#  (('/ram1angadala',), 14),
#  (('/iezepov',), 14),
#  (('/loohai',), 14),
#  (('/ankurv857',), 14),
#  (('/arunsankar',), 14),
#  (('/cauldnz',), 14),
#  (('/brandenkmurray',), 14),
#  (('/twolfanger',), 14),
#  (('/paradesi',), 14),
#  (('/stpise',), 14),
#  (('/wittmaan',), 14),
#  (('/farmerjim',), 14),
#  (('/igwilson',), 14),
#  (('/jwegas',), 14),
#  (('/lrtmonkey',), 14),
#  (('/beiwenwu',), 14),
#  (('/muthujothi',), 14),
#  (('/dougneedham',), 14),
#  (('/alkhwarizmi',), 14),
#  (('/pistnick',), 14),
#  (('/paulhendricks',), 14),
#  (('/strongweng',), 14),
#  (('/shoaib',), 14),
#  (('/przemo',), 14),
#  (('/sujeon',), 14),
#  (('/watsonstevenc',), 14),
#  (('/christopherjthompson',), 14),
#  (('/vinhnguyen',), 14),
#  (('/lali67',), 14),
#  (('/devowl',), 14),
#  (('/belindatrotta',), 14),
#  (('/busterbluth', '/tyronecragg'), 14),
#  (('/stephenritter',), 14),
#  (('/knowledgegrappler',), 14),
#  (('/muditsaxena',), 14),
#  (('/tobycheese',), 14),
#  (('/khanna',), 14),
#  (('/manglam',), 14),
#  (('/jmjtvjoseph',), 14),
#  (('/spock91',), 14),
#  (('/tuanmann',), 14),
#  (('/liweilin',), 14),
#  (('/rouseguy',), 14),
#  (('/adrake',), 14),
#  (('/druidh',), 14),
#  (('/wugang',), 14),
#  (('/taffeylewis',), 14),
#  (('/romaingauthier',), 14),
#  (('/zerrxy',), 14),
#  (('/slideroolz',), 14),
#  (('/manishkk',), 14),
#  (('/trottefox',), 14),
#  (('/mrkimmo',), 14),
#  (('/cmanning',), 14),
#  (('/hardeeparora',), 14),
#  (('/letfoolsdie',), 14),
#  (('/darraghdog',), 14),
#  (('/dariosolari',), 14),
#  (('/lampros',), 14),
#  (('/hnowak',), 14),
#  (('/abalogh',), 14),
#  (('/sj3001',), 14),
#  (('/orchid',), 14),
#  (('/davidthaler',), 14),
#  (('/nizhibitsky',), 14),
#  (('/acarter',), 14),
#  (('/philculliton',), 14),
#  (('/thekannman',), 14),
#  (('/stevendu',), 14),
#  (('/chitrasen',), 14),
#  (('/j0shua',), 14),
#  (('/nlubchenco',), 14),
#  (('/gopalsharma2001',), 14),
#  (('/fennerjw',), 14),
#  (('/solorzano',), 14),
#  (('/prasannakumar2012',), 14),
#  (('/kjanson',), 14),
#  (('/frogeater',), 14),
#  (('/joseffeigl',), 14),
#  (('/takagiwa',), 14),
#  (('/alexginsca',), 14),
#  (('/nandanam',), 14),
#  (('/sergeevii123',), 14),
#  (('/kqdmqx',), 14),
#  (('/rbg143',), 14),
#  (('/yasarc4',), 14),
#  (('/radnado',), 14),
#  (('/ghutty',), 14),
#  (('/dautovri',), 14),
#  (('/bguberfain',), 14),
#  (('/isnani',), 14),
#  (('/kaggle446',), 14),
#  (('/arthurllau',), 14),
#  (('/maheshak04',), 14),
#  (('/pfichou',), 14),
#  (('/rdoume',), 14),
#  (('/rgolovnya',), 14),
#  (('/bigbag1983',), 14),
#  (('/jsphyg',), 14),
#  (('/captaindadja',), 13),
#  (('/mikell',), 13),
#  (('/ampires', '/jbranco'), 13),
#  (('/chalfacre',), 13),
#  (('/derkanat',), 13),
#  (('/jpison',), 13),
#  (('/gpistre',), 13),
#  (('/bakiev',), 13),
#  (('/pavel1',), 13),
#  (('/sergii',), 13),
#  (('/ngcferreira',), 13),
#  (('/evanvanness',), 13),
#  (('/brianbai',), 13),
#  (('/lucienderubempre',), 13),
#  (('/socrates',), 13),
#  (('/maxsop',), 13),
#  (('/sadram',), 13),
#  (('/maneeshkm',), 13),
#  (('/quantability',), 13),
#  (('/poteman',), 13),
#  (('/sureshshanmugam',), 13),
#  (('/martinpoc',), 13),
#  (('/jeannief',), 13),
#  (('/ntumcw',), 13),
#  (('/dariosena',), 13),
#  (('/efimov',), 13),
#  (('/digitalbro',), 13),
#  (('/jeeban',), 13),
#  (('/azacharia',), 13),
#  (('/superking',), 13),
#  (('/suryavanshi',), 13),
#  (('/orikron',), 13),
#  (('/zsaurk',), 13),
#  (('/eddyod',), 13),
#  (('/namesj',), 13),
#  (('/puyokw',), 13),
#  (('/pythia',), 13),
#  (('/papadopc',), 13),
#  (('/ddrbcn',), 13),
#  (('/varg54',), 13),
#  (('/onepau',), 13),
#  (('/jayhawk1900',), 13),
#  (('/lizasheina',), 13),
#  (('/lisali',), 13),
#  (('/pritam108',), 13),
#  (('/mariofilho',), 13),
#  (('/guppi3695',), 13),
#  (('/wliping',), 13),
#  (('/agrawalvikas',), 13),
#  (('/paulperry',), 13),
#  (('/amortized',), 13),
#  (('/hpeaker',), 13),
#  (('/jpopham91',), 13),
#  (('/del=e892e8b55e7c8494',), 13),
#  (('/gregchase',), 13),
#  (('/konstkor',), 13),
#  (('/sravanb',), 13),
#  (('/maddula',), 13),
#  (('/rajkumarb',), 13),
#  (('/pinocchio',), 13),
#  ...]
